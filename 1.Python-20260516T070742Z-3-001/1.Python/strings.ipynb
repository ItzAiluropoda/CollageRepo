# %%
"Arithmetics"
name_os='Harry Osborn'
goblin="Norman 2435"
print(name_os,goblin ,"\n")
# Out:
# Harry Osborn Norman 2435

# %%
"!@#$%^&*({}:<>:?{}"
# Out:
# '!@#$%^&*({}:<>:?{}'

# %%
print("HELLOO")
# Out:
# HELLOO

# %%
name="Michial Myers"
print(name)
# Out:
# Michial Myers

# %%
index=0
index_reverse=-len(name)
for i in name:
    print('[',i,'[',index,']','[',index_reverse,']',']')
    index+=1
    index_reverse+=1
# Out:
# [ M [ 0 ] [ -13 ] ]
# [ i [ 1 ] [ -12 ] ]
# [ c [ 2 ] [ -11 ] ]
# [ h [ 3 ] [ -10 ] ]
# [ i [ 4 ] [ -9 ] ]
# [ a [ 5 ] [ -8 ] ]
# [ l [ 6 ] [ -7 ] ]
# [   [ 7 ] [ -6 ] ]
# [ M [ 8 ] [ -5 ] ]
# [ y [ 9 ] [ -4 ] ]
# [ e [ 10 ] [ -3 ] ]
# [ r [ 11 ] [ -2 ] ]
# [ s [ 12 ] [ -1 ] ]

# %%
name[::-1]
# Out:
# 'sreyM laihciM'

# %%
statement="It is not "+name+" its Michael Myers"
statement
# Out:
# 'It is not Michial Myers its Michael Myers'

# %%
name_os*3
# Out:
# 'Harry OsbornHarry OsbornHarry Osborn'

# %%
print(name,"\t\t\t\t",name_os,'\n')
# Out:
# Michial Myers 				 Harry Osborn

# %%
k=name.upper()
print(k)
print(name_os.lower())
# Out:
# MICHIAL MYERS
# harry osborn

# %%
o="hife ihfjs oBj bg l vb"
b=o.capitalize()
print(b,o.title())
# Out:
# Hife ihfjs obj bg l vb Hife Ihfjs Obj Bg L Vb

# %%
name2=name.replace("Michial","Michael")
name2
# Out:
# 'Michael Myers'

# %%
z="hi ji ki"
print(z.find("i"))
# Out:
# 1
