# %%
t1 = (1, 2)
t2 = (3, 4)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4)

# %%
t2 = (1, 2)
print(t2 * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
tlen = (1, 2, 3, 4)
print(len(tlen))
# Out:
# 4

# %%
tcount = (1, 2, 2, 3)
print(tcount.count(2))
# Out:
# 2

# %%
tindex = (10, 20, 30, 20)
print(tindex.index(20))
# Out:
# 1

# %%
tsort = (5, 2, 9, 1)
print(sorted(tsort))
# Out:
# [1, 2, 5, 9]

# %%
mint= (5, 2, 9, 1)
print(min(mint))
# Out:
# 9

# %%
MAXt = (5, 2, 9, 1)
print(max(MAXt))
# Out:
# 1

# %%
x=1
y=2
z=3
tp = z,y,z
print(tp)
# Out:
# (1, 2, 3)

# %%
tup = (10, 20, 30)
x, y, z = tup
print(x, y, z)
# Out:
# 10 20 30
