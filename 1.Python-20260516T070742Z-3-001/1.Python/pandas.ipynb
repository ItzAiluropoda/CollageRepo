# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={"a":10,"b":20,"c":30}
my_list
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1=pd.Series([1,2,3,4],index=["USA","Germany","USSR","Japan"])
ser2=pd.Series([1,2,3,4],index=["USA","Germany","Italy","Japan"])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      3
# Japan      4
# dtype: int64

# %%
ser1+ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser1['USA']
# Out:
# np.int64(1)

# %%
from numpy.random import randn
np.random.seed(200)

# %%
df=pd.DataFrame(randn(5,4),index="A B C D E".split(),columns="W X Y Z".split())

# %%
df
# Out:
#           W         X         Y         Z
# A -1.450948  1.910953  0.711879 -0.247738
# B  0.361466 -0.032950 -0.221347  0.477257
# C -0.691939  0.792006  0.073249  1.303286
# D  0.213481  1.017349  1.911712 -0.529672
# E  1.842135 -1.057235 -0.862916  0.237631

# %%
df['W']
# Out:
# A   -1.450948
# B    0.361466
# C   -0.691939
# D    0.213481
# E    1.842135
# Name: W, dtype: float64

# %%
df['new']=df['W']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -1.450948  1.910953  0.711879 -0.247738 -0.739069
# B  0.361466 -0.032950 -0.221347  0.477257  0.140120
# C -0.691939  0.792006  0.073249  1.303286 -0.618690
# D  0.213481  1.017349  1.911712 -0.529672  2.125193
# E  1.842135 -1.057235 -0.862916  0.237631  0.979219

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -1.450948  1.910953  0.711879 -0.247738
# B  0.361466 -0.032950 -0.221347  0.477257
# C -0.691939  0.792006  0.073249  1.303286
# D  0.213481  1.017349  1.911712 -0.529672
# E  1.842135 -1.057235 -0.862916  0.237631

# %%
df.drop("E",axis=0)
# Out:
#           W         X         Y         Z
# A -1.450948  1.910953  0.711879 -0.247738
# B  0.361466 -0.032950 -0.221347  0.477257
# C -0.691939  0.792006  0.073249  1.303286
# D  0.213481  1.017349  1.911712 -0.529672

# %%
df.loc['A']
# Out:
# W   -1.450948
# X    1.910953
# Y    0.711879
# Z   -0.247738
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -0.691939
# X    0.792006
# Y    0.073249
# Z    1.303286
# Name: C, dtype: float64

# %%
df.loc["B","Y"]
# Out:
# np.float64(-0.2213467176273389)

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -1.450948  0.711879
# B  0.361466 -0.221347

# %%
df
# Out:
#           W         X         Y         Z
# A -1.450948  1.910953  0.711879 -0.247738
# B  0.361466 -0.032950 -0.221347  0.477257
# C -0.691939  0.792006  0.073249  1.303286
# D  0.213481  1.017349  1.911712 -0.529672
# E  1.842135 -1.057235 -0.862916  0.237631

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True   True  False
# B   True  False  False   True
# C  False   True   True   True
# D   True   True   True  False
# E   True  False  False   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  1.910953  0.711879       NaN
# B  0.361466       NaN       NaN  0.477257
# C       NaN  0.792006  0.073249  1.303286
# D  0.213481  1.017349  1.911712       NaN
# E  1.842135       NaN       NaN  0.237631

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  0.361466 -0.032950 -0.221347  0.477257
# D  0.213481  1.017349  1.911712 -0.529672
# E  1.842135 -1.057235 -0.862916  0.237631

# %%
df[df['W']>0]['Y']
# Out:
# B   -0.221347
# D    1.911712
# E   -0.862916
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# B -0.221347 -0.032950
# D  1.911712  1.017349
# E -0.862916 -1.057235

# %%
df[(df['W']>0)&(df['Y']>1)]
# Out:
#           W         X         Y         Z
# D  0.213481  1.017349  1.911712 -0.529672

# %%
mdf=pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
mdf
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
mdf.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
mdf.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
mdf.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
mdf.fillna(value=mdf.mean())
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3

# %%
data={"Company":['GOOG','GOOG','MSFT','MSFT','FB','FB'],
      "Person":['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
      'Sales':[200,120,340,124,243,350]}

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350>

# %%
df1.columns
# Out:
# Index(['Company', 'Person', 'Sales'], dtype='object')

# %%
df1.Company.unique()
# Out:
# array(['GOOG', 'MSFT', 'FB'], dtype=object)

# %%
by_comp=df1.groupby('Company')

# %%
by_comp

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.std(numeric_only=True)
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.mean(numeric_only=True)
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
by_comp.min(numeric_only=True)
# Out:
#          Sales
# Company
# FB         243
# GOOG       120
# MSFT       124

# %%
left = pd.DataFrame({"key": ["K0", "K1", "K2", "K3"],
                    "A": ["A0", "A1", "A2", "A3"],
                    "B": ["B0", "B1", "B2", "B3"]})
right = pd.DataFrame({"key": ["K0", "K1", "K2", "K3"],
                      "C": ["C0", "C1", "C2", "C3"],
                      "D": ["D0", "D1", "D2", "D3"],})
result = pd.merge(left, right, on="key")
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left1=pd.DataFrame({'A':['A0','A1','A2'],
                    'B':['B0','B1','B2']},
                    index=['K0','K1','K2'])
right1=pd.DataFrame({'C':['C0','C1','C2'],
                    'D':['D0','D1','D2']},
                    index=['K0','K2','K3'])

# %%
left1.join(right1)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
right1.join(left1)
# Out:
#      C   D    A    B
# K0  C0  D0   A0   B0
# K2  C1  D1   A2   B2
# K3  C2  D2  NaN  NaN

# %%
left1.join(right1,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2

# %%
sal=pd.read_csv("G:\\Projects\\Code\\EXTRA\\DATA\\Salaries (1).csv")

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal['BasePay'].mean()
# Out:
# np.float64(66325.44884048769)

# %%
sal['OvertimePay'].max()
# Out:
# np.float64(245131.88)

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]['EmployeeName']
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
sal['title_len']=sal['JobTitle'].apply(len)

# %%
sal[['title_len','TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %%
#print no' of jobs with chief
c=0
jobs=sal['JobTitle']
for i in jobs:
    if "chief" in i.lower():
        c+=1
print(c)
# Out:
# 627

# %%
def name_find(a,name):
    if a.lower() in name.lower():
        return True
    else:
        return False
sum(sal['JobTitle'].apply(lambda x: name_find("Chief",x)))
# Out:
# 627
