# %%
a=5
a==6
# Out:
# False

# %%
a!=6
# Out:
# True

# %%
"A">"B"
# Out:
# False

# %%
"BA">"AB"
# Out:
# True

# %%
"BB">"BA"
# Out:
# True

# %%
age=19
if age>18:
    print("Enter")
else:
    print("go")
# Out:
# Enter

# %%
age=18
if age>18:
    print("Enter")
elif age==18:
    print("close")
else:
    print("go")
# Out:
# close

# %%
num=50
if (num>20)and(num<60):
    print("num b/w 60 & 20")
print("ok")
# Out:
# num b/w 60 & 20
# ok

# %%
str="rick"
if (str=="rick") or (str=="jass"):
    print("its either rick or jass or both")
else:
    print("its neither rick or jass")
# Out:
# its either rick or jass or both

# %%
str="john"
if not (str=="rick"):
    print("its not rick")
# Out:
# its not rick

# %%
str1="John"
str2="john"
if str1=="john":
    print("st1 is john")
if str2=="john":
    print("st2 is john")
# Out:
# st2 is john
